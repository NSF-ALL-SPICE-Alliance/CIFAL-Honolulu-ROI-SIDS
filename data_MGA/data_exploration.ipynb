# %%
import pandas as pd

# %%
country_data = pd.read_csv('~/Documents/Monitoring-Global-Development-Aid-With-Machine-Learning/Data/activity_cluster_data.csv')

country_data
# Out:
#         Year RecipientName  cluster  USD_Disbursement country_code  \
# 0       2000   Afghanistan        2          0.000000          AFG
# 1       2000   Afghanistan        5          5.944185          AFG
# 2       2000   Afghanistan       11          0.683999          AFG
# 3       2000   Afghanistan       12          0.708639          AFG
# 4       2000   Afghanistan       13          0.086285          AFG
# ...      ...           ...      ...               ...          ...
# 297642  2019      Zimbabwe      211          4.147414          ZWE
# 297643  2019      Zimbabwe      214          1.120344          ZWE
# 297644  2019      Zimbabwe      221          0.050000          ZWE
# 297645  2019      Zimbabwe      225         23.510779          ZWE
# 297646  2019      Zimbabwe      226          0.000000          ZWE
#
#        IncomegroupName                       Sector
# 0                 LDCs                       Health
# 1                 LDCs  Refugees in Donor Countries
# ...

# %%
country_data.RecipientName.unique()
# Out:
# array(['Afghanistan', 'Africa, regional', 'Albania', 'Algeria',
#        'America, regional', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Asia, regional', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belize', 'Benin', 'Bhutan',
#        'Bilateral, unspecified', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Burkina Faso', 'Burundi', 'Cabo Verde',
#        'Cambodia', 'Cameroon', 'Central African Republic',
#        'Central Asia, regional', 'Chad', 'Chile',
#        "China (People's Republic of)", 'Colombia', 'Comoros', 'Congo',
#        'Cook Islands', 'Costa Rica', 'Croatia', 'Cuba', "Côte d'Ivoire",
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia',
# ...

# %%
sids = ['Anguilla', 'Antigua and Barbuda', 'Bahrain', 'Barbados', 'Belize', 'Cabo Verde', 'Comoros', 
             'Cook Islands', 'Dominica', 'Dominican Republic', 'Fiji', 'Grenada', 'Guinea-Bissau', 'Guyana', 
             'Haiti', 'Jamaica', 'Kiribati', 'Maldives', 'Marshall Islands', 'Mauritius', 'Micronesia', 
             'Montserrat', 'Nauru', 'Niue', 'Palau', 'Papua New Guinea', 'Saint Kitts and Nevis', 'Saint Lucia', 
             'Saint Vincent and the Grenadines', 'Samoa', 'Sao Tome and Principe', 'Seychelles', 'Solomon Islands', 
             'Suriname', 'Timor-Leste', 'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Turks and Caicos Islands', 
             'Tuvalu', 'Vanuatu']

# %%
sids_data = country_data[country_data['RecipientName'].isin(sids)]

sids_data
# Out:
#         Year RecipientName  cluster  USD_Disbursement country_code  \
# 374     2000      Anguilla       19          0.015138          AIA
# 375     2000      Anguilla       29          0.000922          AIA
# 376     2000      Anguilla       31          0.134726          AIA
# 377     2000      Anguilla       38          0.000000          AIA
# 378     2000      Anguilla       58          0.236149          AIA
# ...      ...           ...      ...               ...          ...
# 296779  2019       Vanuatu      212          0.082345          VUT
# 296780  2019       Vanuatu      213          0.000000          VUT
# 296781  2019       Vanuatu      214          0.020712          VUT
# 296782  2019       Vanuatu      216          0.033270          VUT
# 296783  2019       Vanuatu      227          0.209376          VUT
#
#        IncomegroupName                      Sector
# 374             MADCTs                      Energy
# 375             MADCTs                     Tourism
# ...

# %%
country_data.Sector.unique()
# Out:
# array(['Health', 'Refugees in Donor Countries',
#        'Conflict, Peace & Security', 'Government & Civil Society',
#        'Other Multisector', 'Emergency Response', 'Energy', 'Education',
#        'Agriculture', 'Water Supply & Sanitation', 'Transport',
#        'Social Infrastructure & Services',
#        'Developmental Food Aid/Food Security Assistance',
#        'Reconstruction Relief & Rehabilitation', 'Environment',
#        'Mineral Resources & Mining', 'General Budget Support',
#        'Population Policies/Programmes', 'Business & Other Services',
#        'Trade Policies & Regulations', 'Industry', 'Forestry',
#        'Communications', 'Fishing', 'Banking & Financial Services',
#        'Action Relating to Debt', 'Tourism', 'Culture',
#        'Solid Waste and Recycling',
#        'Safety of nuclear power plants and safeguards',
#        'Volunteer Programs & Services'], dtype=object)

# %%
data2 = pd.read_excel('~/Documents/Monitoring-Global-Development-Aid-With-Machine-Learning/Data/descriptive_statistics_clusters.xlsx')
data2
# Out:
#      Cluster                                              Topic  \
# 0         56                                     Relief of debt
# 1          6                                 Irrigation systems
# 2         49                           Agricultural development
# 3         63  Agricultural research, development and technol...
# 4         99               Agricultural alternative development
# ..       ...                                                ...
# 168       68                          Water resource management
# 169       72                        Water supply and sanitation
# 170       76                             River basin management
# 171      121                        Water policy and governance
# 172      208                Sanitation and wastewater treatment
#
#     matching Purpose Code Purpose Code                       Area  \
# 0                     yes  60030/60020    Action Relating to Debt
# ...
